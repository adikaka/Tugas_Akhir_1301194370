# %%
import pandas as pd

# %%
df_MI = pd.read_csv(dwn_url)
df_MI = df_MI.drop('Unnamed: 0', axis=1)

# %%
df_MI
# Out:
#      Mean_wavelet  Std_wavelet  Max_wavelet  Min_wavelet   Med_wavelet  \
# 0   -1.140296e-07     0.000368     0.005660    -0.005296  7.366450e-09
# 1   -3.237428e-08     0.000409     0.004027    -0.004133  1.300959e-09
# 2    3.716743e-08     0.000296     0.004981    -0.007905  1.183576e-09
# 3    1.435873e-09     0.000511     0.010863    -0.008997  5.162848e-10
# 4    1.692980e-08     0.000206     0.003113    -0.003379 -1.464605e-09
# ..            ...          ...          ...          ...           ...
# 275 -3.866203e-08     0.000644     0.012823    -0.016201  1.426908e-21
# 276  7.044467e-09     0.000270     0.010633    -0.007747 -3.964177e-12
# 277 -1.093870e-08     0.000329     0.005776    -0.009169  2.475347e-09
# 278  2.153113e-09     0.000132     0.002568    -0.001801 -7.646064e-11
# 279  1.583342e-09     0.000061     0.000844    -0.000943  2.534479e-22
#
#       Var_wavelet  Skew_wavelet    Q1_wavelet    Q3_wavelet   IQR_wavelet  \
# 0    1.351754e-07     -0.526047 -6.491013e-07  6.968827e-07  1.345984e-06
# 1    1.672393e-07     -0.467733 -2.533549e-06  2.624170e-06  5.157720e-06
# 2    8.746432e-08     -0.233113 -1.128254e-06  1.141965e-06  2.270219e-06
# 3    2.614612e-07      0.093306 -2.598059e-06  2.369187e-06  4.967246e-06
# 4    4.239165e-08     -0.049948 -4.891431e-07  4.654809e-07  9.546240e-07
# ..            ...           ...           ...           ...           ...
# 275  4.144554e-07     -1.820804 -2.231395e-07  2.643018e-07  4.874413e-07
# 276  7.268914e-08      2.874972 -2.881598e-07  2.912042e-07  5.793640e-07
# 277  1.080994e-07     -1.282230 -4.867813e-07  4.966234e-07  9.834047e-07
# 278  1.750877e-08      1.222098 -6.360359e-07  6.413088e-07  1.277345e-06
# 279  3.742280e-09      0.248881 -5.793759e-07  5.904872e-07  1.169863e-06
#
#      MinMax_wavelet  Kurt_wavelet
# 0          0.010956     64.324412
# 1          0.008160     23.393347
# 2          0.012886     60.637048
# 3          0.019861     58.236027
# 4          0.006492     48.848373
# ..              ...           ...
# 275        0.029024    160.049238
# 276        0.018380    220.130953
# 277        0.014945    164.803097
# 278        0.004369     55.052190
# 279        0.001788     49.623220
#
# [280 rows x 12 columns]

# %%
df_MI['Label']=1

# %%
df_MI
# Out:
#      Mean_wavelet  Std_wavelet  Max_wavelet  Min_wavelet   Med_wavelet  \
# 0   -1.140296e-07     0.000368     0.005660    -0.005296  7.366450e-09
# 1   -3.237428e-08     0.000409     0.004027    -0.004133  1.300959e-09
# 2    3.716743e-08     0.000296     0.004981    -0.007905  1.183576e-09
# 3    1.435873e-09     0.000511     0.010863    -0.008997  5.162848e-10
# 4    1.692980e-08     0.000206     0.003113    -0.003379 -1.464605e-09
# ..            ...          ...          ...          ...           ...
# 275 -3.866203e-08     0.000644     0.012823    -0.016201  1.426908e-21
# 276  7.044467e-09     0.000270     0.010633    -0.007747 -3.964177e-12
# 277 -1.093870e-08     0.000329     0.005776    -0.009169  2.475347e-09
# 278  2.153113e-09     0.000132     0.002568    -0.001801 -7.646064e-11
# 279  1.583342e-09     0.000061     0.000844    -0.000943  2.534479e-22
#
#       Var_wavelet  Skew_wavelet    Q1_wavelet    Q3_wavelet   IQR_wavelet  \
# 0    1.351754e-07     -0.526047 -6.491013e-07  6.968827e-07  1.345984e-06
# 1    1.672393e-07     -0.467733 -2.533549e-06  2.624170e-06  5.157720e-06
# 2    8.746432e-08     -0.233113 -1.128254e-06  1.141965e-06  2.270219e-06
# 3    2.614612e-07      0.093306 -2.598059e-06  2.369187e-06  4.967246e-06
# 4    4.239165e-08     -0.049948 -4.891431e-07  4.654809e-07  9.546240e-07
# ..            ...           ...           ...           ...           ...
# 275  4.144554e-07     -1.820804 -2.231395e-07  2.643018e-07  4.874413e-07
# 276  7.268914e-08      2.874972 -2.881598e-07  2.912042e-07  5.793640e-07
# 277  1.080994e-07     -1.282230 -4.867813e-07  4.966234e-07  9.834047e-07
# 278  1.750877e-08      1.222098 -6.360359e-07  6.413088e-07  1.277345e-06
# 279  3.742280e-09      0.248881 -5.793759e-07  5.904872e-07  1.169863e-06
#
#      MinMax_wavelet  Kurt_wavelet  Label
# 0          0.010956     64.324412      1
# 1          0.008160     23.393347      1
# 2          0.012886     60.637048      1
# 3          0.019861     58.236027      1
# 4          0.006492     48.848373      1
# ..              ...           ...    ...
# 275        0.029024    160.049238      1
# 276        0.018380    220.130953      1
# 277        0.014945    164.803097      1
# 278        0.004369     55.052190      1
# 279        0.001788     49.623220      1
#
# [280 rows x 13 columns]

# %%
df_N = pd.read_csv(dwn_url)
df_N = df_N.drop('Unnamed: 0', axis=1)
df_N['Label']=0

# %%
df_N
# Out:
#      Mean_wavelet  Std_wavelet  Max_wavelet  Min_wavelet   Med_wavelet  \
# 0   -7.025808e-09     0.000066     0.002409    -0.001755 -3.749471e-22
# 1   -1.556067e-08     0.000124     0.003158    -0.002600  7.276224e-10
# 2   -5.383644e-08     0.000450     0.004558    -0.005261 -9.319693e-09
# 3    1.502731e-06     0.000743     0.010726    -0.007889  2.350813e-09
# 4   -3.103035e-08     0.000415     0.008534    -0.005778 -2.972175e-09
# ..            ...          ...          ...          ...           ...
# 275  1.334908e-07     0.000284     0.004540    -0.004703 -6.134837e-09
# 276  1.452190e-08     0.000117     0.003222    -0.003165 -4.909419e-22
# 277 -6.577933e-09     0.000365     0.008719    -0.011868 -4.248742e-09
# 278  1.130831e-08     0.000206     0.007822    -0.008486  5.507791e-09
# 279  1.966960e-08     0.000134     0.002852    -0.002135  6.029921e-10
#
#       Var_wavelet  Skew_wavelet    Q1_wavelet    Q3_wavelet   IQR_wavelet  \
# 0    4.341976e-09      2.474493 -3.122490e-07  2.651061e-07  5.773551e-07
# 1    1.528059e-08      0.828237 -4.003604e-07  4.077891e-07  8.081496e-07
# 2    2.021535e-07     -1.024515 -4.570763e-06  3.608785e-06  8.179548e-06
# 3    5.527448e-07      2.231036 -1.797313e-06  1.679290e-06  3.476603e-06
# 4    1.726204e-07      2.228800 -8.610364e-06  8.691581e-06  1.730195e-05
# ..            ...           ...           ...           ...           ...
# 275  8.055901e-08      1.263980 -5.707461e-06  5.104442e-06  1.081190e-05
# 276  1.380280e-08     -0.170160 -6.741095e-08  6.442572e-08  1.318367e-07
# 277  1.332748e-07     -1.202629 -1.077026e-05  9.278368e-06  2.004863e-05
# 278  4.241861e-08     -0.202955 -1.085348e-06  1.310656e-06  2.396003e-06
# 279  1.791184e-08      1.267905 -2.605032e-06  2.717337e-06  5.322369e-06
#
#      MinMax_wavelet  Kurt_wavelet  Label
# 0          0.004165    252.797301      0
# 1          0.005757    180.526298      0
# 2          0.009819     38.084787      0
# 3          0.018615     56.758168      0
# 4          0.014312     84.818655      0
# ..              ...           ...    ...
# 275        0.009243     42.542479      0
# 276        0.006387    124.545291      0
# 277        0.020587     75.172558      0
# 278        0.016308    383.436922      0
# 279        0.004986     57.615907      0
#
# [280 rows x 13 columns]

# %%
df_W = pd.concat([df_MI, df_N])
df_W
# Out:
#      Mean_wavelet  Std_wavelet  Max_wavelet  Min_wavelet   Med_wavelet  \
# 0   -1.140296e-07     0.000368     0.005660    -0.005296  7.366450e-09
# 1   -3.237428e-08     0.000409     0.004027    -0.004133  1.300959e-09
# 2    3.716743e-08     0.000296     0.004981    -0.007905  1.183576e-09
# 3    1.435873e-09     0.000511     0.010863    -0.008997  5.162848e-10
# 4    1.692980e-08     0.000206     0.003113    -0.003379 -1.464605e-09
# ..            ...          ...          ...          ...           ...
# 275  1.334908e-07     0.000284     0.004540    -0.004703 -6.134837e-09
# 276  1.452190e-08     0.000117     0.003222    -0.003165 -4.909419e-22
# 277 -6.577933e-09     0.000365     0.008719    -0.011868 -4.248742e-09
# 278  1.130831e-08     0.000206     0.007822    -0.008486  5.507791e-09
# 279  1.966960e-08     0.000134     0.002852    -0.002135  6.029921e-10
#
#       Var_wavelet  Skew_wavelet    Q1_wavelet    Q3_wavelet   IQR_wavelet  \
# 0    1.351754e-07     -0.526047 -6.491013e-07  6.968827e-07  1.345984e-06
# 1    1.672393e-07     -0.467733 -2.533549e-06  2.624170e-06  5.157720e-06
# 2    8.746432e-08     -0.233113 -1.128254e-06  1.141965e-06  2.270219e-06
# 3    2.614612e-07      0.093306 -2.598059e-06  2.369187e-06  4.967246e-06
# 4    4.239165e-08     -0.049948 -4.891431e-07  4.654809e-07  9.546240e-07
# ..            ...           ...           ...           ...           ...
# 275  8.055901e-08      1.263980 -5.707461e-06  5.104442e-06  1.081190e-05
# 276  1.380280e-08     -0.170160 -6.741095e-08  6.442572e-08  1.318367e-07
# 277  1.332748e-07     -1.202629 -1.077026e-05  9.278368e-06  2.004863e-05
# 278  4.241861e-08     -0.202955 -1.085348e-06  1.310656e-06  2.396003e-06
# 279  1.791184e-08      1.267905 -2.605032e-06  2.717337e-06  5.322369e-06
#
#      MinMax_wavelet  Kurt_wavelet  Label
# 0          0.010956     64.324412      1
# 1          0.008160     23.393347      1
# 2          0.012886     60.637048      1
# 3          0.019861     58.236027      1
# 4          0.006492     48.848373      1
# ..              ...           ...    ...
# 275        0.009243     42.542479      0
# 276        0.006387    124.545291      0
# 277        0.020587     75.172558      0
# 278        0.016308    383.436922      0
# 279        0.004986     57.615907      0
#
# [560 rows x 13 columns]

# %%
def norm(df):
  df = (df - df.min()) / (df.max() - df.min())
  return df

# %%
import random

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Contoh data
datapca_w = df_W.drop(columns=['Label'])
datapca_w = norm(datapca_w)

# Mengubah DataFrame menjadi numpy array
X = datapca_w.values

# Inisialisasi objek PCA dengan jumlah komponen utama yang sama dengan jumlah fitur
num_components = X.shape[1]
pca = PCA(n_components=num_components)

# Lakukan PCA pada tiap fitur (kolom)
pca.fit(X)

# Dapatkan proporsi varians yang dijelaskan oleh tiap komponen utama
explained_variance_ratio = pca.explained_variance_ratio_

# Output proporsi varians (nilai PCA) untuk tiap fitur
for i, ratio in enumerate(explained_variance_ratio):
    print(f"Nilai PCA untuk {datapca_w.columns[i]}: {ratio:.4f}")
# Out:
# Nilai PCA untuk Mean_wavelet: 0.9538
# Nilai PCA untuk Std_wavelet: 0.8897
# Nilai PCA untuk Max_wavelet: 0.6373
# Nilai PCA untuk Min_wavelet: 0.6896
# Nilai PCA untuk Med_wavelet: 0.7240
# Nilai PCA untuk Var_wavelet: 0.6293
# Nilai PCA untuk Skew_wavelet: 0.7270
# Nilai PCA untuk Q1_wavelet: 0.7777
# Nilai PCA untuk Q3_wavelet: 0.6438
# Nilai PCA untuk IQR_wavelet: 0.7317
# Nilai PCA untuk MinMax_wavelet: 0.7479
# Nilai PCA untuk Kurt_wavelet: 0.6039

# %%
df_W = df_W.drop('Max_wavelet', axis=1)
df_W = df_W.drop('Min_wavelet', axis=1)
df_W = df_W.drop('Var_wavelet', axis=1)
df_W = df_W.drop('Q3_wavelet', axis=1)
df_W = df_W.drop('Kurt_wavelet', axis=1)
df_W
# Out:
#      Mean_wavelet  Std_wavelet   Med_wavelet  Skew_wavelet    Q1_wavelet  \
# 0   -1.140296e-07     0.000368  7.366450e-09     -0.526047 -6.491013e-07
# 1   -3.237428e-08     0.000409  1.300959e-09     -0.467733 -2.533549e-06
# 2    3.716743e-08     0.000296  1.183576e-09     -0.233113 -1.128254e-06
# 3    1.435873e-09     0.000511  5.162848e-10      0.093306 -2.598059e-06
# 4    1.692980e-08     0.000206 -1.464605e-09     -0.049948 -4.891431e-07
# ..            ...          ...           ...           ...           ...
# 275  1.334908e-07     0.000284 -6.134837e-09      1.263980 -5.707461e-06
# 276  1.452190e-08     0.000117 -4.909419e-22     -0.170160 -6.741095e-08
# 277 -6.577933e-09     0.000365 -4.248742e-09     -1.202629 -1.077026e-05
# 278  1.130831e-08     0.000206  5.507791e-09     -0.202955 -1.085348e-06
# 279  1.966960e-08     0.000134  6.029921e-10      1.267905 -2.605032e-06
#
#       IQR_wavelet  MinMax_wavelet  Label
# 0    1.345984e-06        0.010956      1
# 1    5.157720e-06        0.008160      1
# 2    2.270219e-06        0.012886      1
# 3    4.967246e-06        0.019861      1
# 4    9.546240e-07        0.006492      1
# ..            ...             ...    ...
# 275  1.081190e-05        0.009243      0
# 276  1.318367e-07        0.006387      0
# 277  2.004863e-05        0.020587      0
# 278  2.396003e-06        0.016308      0
# 279  5.322369e-06        0.004986      0
#
# [560 rows x 8 columns]

# %% [markdown]
# **MFCC**

# %%
df_MI_MFCC = pd.read_csv(dwn_url)
df_MI_MFCC = df_MI_MFCC.drop('Unnamed: 0', axis=1)
df_MI_MFCC['Label']=1

# %%
df_MI_MFCC
# Out:
#      Mean_mfcc   Std_mfcc   Max_mfcc    Min_mfcc  Med_mfcc   Var_mfcc  \
# 0   -43.426044  219.93683  158.66292 -1018.71075  0.013834  48372.207
# 1   -41.027546  219.84988  163.84500 -1021.74493  1.801707  48333.970
# 2   -42.735283  224.17154  185.06921 -1040.87920  1.231523  50252.880
# 3   -38.869167  207.17107  160.68805  -960.26050  1.259501  42919.848
# 4   -44.457184  230.23308  155.71140 -1065.97700  0.058005  53007.273
# ..         ...        ...        ...         ...       ...        ...
# 275 -39.438744  195.23941  150.00613  -899.27630  0.000000  38118.426
# 276 -45.569940  224.75117  254.44476 -1037.77890  0.000000  50513.090
# 277 -45.345917  213.19688  182.77911  -986.10550  0.000000  45452.914
# 278 -47.315910  237.74356  167.35643 -1103.01950  0.020380  56522.000
# 279 -50.148850  242.87128  157.48892 -1131.37080  0.000000  58986.457
#
#      Skew_mfcc   Q1_mfcc    Q3_mfcc   IQR_mfcc  MinMax_mfcc  Kurt_mfcc  Label
# 0    -4.104066  0.000000   7.543952   7.543952    1177.3737  14.925378      1
# 1    -4.094527 -0.064156  12.803530  12.867687    1185.5900  14.876037      1
# 2    -4.088933 -0.938724   8.764449   9.703173    1225.9484  14.851157      1
# 3    -4.101749  0.000000  11.384340  11.384340    1120.9485  14.912424      1
# 4    -4.101333  0.000000   9.393891   9.393891    1221.6885  14.910316      1
# ..         ...       ...        ...        ...          ...        ...    ...
# 275  -4.116523  0.000000   5.870569   5.870569    1049.2825  14.987295      1
# 276  -4.099612  0.000000   5.338897   5.338897    1292.2236  14.912520      1
# 277  -4.105257  0.000000   0.089661   0.089661    1168.8846  14.933640      1
# 278  -4.097839 -0.390935   9.337014   9.727949    1270.3760  14.893764      1
# 279  -4.093377 -1.163532   6.271840   7.435372    1288.8597  14.871114      1
#
# [280 rows x 13 columns]

# %%
df_N_MFCC = pd.read_csv(dwn_url)
df_N_MFCC = df_N_MFCC.drop('Unnamed: 0', axis=1)
df_N_MFCC['Label']=0

# %%
df_N_MFCC
# Out:
#      Mean_mfcc   Std_mfcc   Max_mfcc    Min_mfcc  Med_mfcc   Var_mfcc  \
# 0   -48.981632  239.73557  202.14815 -1119.36080  0.000000  57473.145
# 1   -45.290043  226.40605  153.91306 -1048.60410  0.000000  51259.700
# 2   -40.691204  218.82877  171.80734 -1019.07355  2.255058  47886.027
# 3   -39.477356  206.10468  118.30521  -953.92896  0.315327  42479.137
# 4   -41.954914  211.82599  202.16441  -997.42140  0.000000  44870.250
# ..         ...        ...        ...         ...       ...        ...
# 275 -42.938380  225.72484  187.77933 -1060.25730  0.166365  50951.703
# 276 -50.174990  243.28606  266.70163 -1124.38320  0.000000  59188.105
# 277 -40.708973  212.33914  209.92316 -1000.77600  0.076779  45087.910
# 278 -41.788986  221.50528  188.73383 -1027.59060  0.389086  49064.586
# 279 -47.161606  235.76474  205.15549 -1107.70810  0.069018  55585.010
#
#      Skew_mfcc   Q1_mfcc    Q3_mfcc   IQR_mfcc  MinMax_mfcc  Kurt_mfcc  Label
# 0    -4.083991 -0.030342   5.468998   5.499341    1321.5090  14.827144      0
# 1    -4.101421  0.000000   7.191274   7.191274    1202.5172  14.911211      0
# 2    -4.087075  0.000000  13.019967  13.019967    1190.8809  14.839055      0
# 3    -4.103584  0.000000   9.121133   9.121133    1072.2341  14.920605      0
# 4    -4.055674 -2.708147   8.719538  11.427685    1199.5858  14.686587      0
# ..         ...       ...        ...        ...          ...        ...    ...
# 275  -4.066482 -2.523454  10.922972  13.446426    1248.0366  14.738029      0
# 276  -4.097396  0.000000   4.631042   4.631042    1391.0848  14.903465      0
# 277  -4.050197 -1.776793  10.533521  12.310314    1210.6992  14.664722      0
# 278  -4.090141  0.000000   9.448184   9.448184    1216.3245  14.854414      0
# 279  -4.070286 -3.213782   9.130609  12.344391    1312.8636  14.758332      0
#
# [280 rows x 13 columns]

# %%
df_MFCC = pd.concat([df_MI_MFCC, df_N_MFCC])
df_MFCC
# Out:
#      Mean_mfcc   Std_mfcc   Max_mfcc    Min_mfcc  Med_mfcc   Var_mfcc  \
# 0   -43.426044  219.93683  158.66292 -1018.71075  0.013834  48372.207
# 1   -41.027546  219.84988  163.84500 -1021.74493  1.801707  48333.970
# 2   -42.735283  224.17154  185.06921 -1040.87920  1.231523  50252.880
# 3   -38.869167  207.17107  160.68805  -960.26050  1.259501  42919.848
# 4   -44.457184  230.23308  155.71140 -1065.97700  0.058005  53007.273
# ..         ...        ...        ...         ...       ...        ...
# 275 -42.938380  225.72484  187.77933 -1060.25730  0.166365  50951.703
# 276 -50.174990  243.28606  266.70163 -1124.38320  0.000000  59188.105
# 277 -40.708973  212.33914  209.92316 -1000.77600  0.076779  45087.910
# 278 -41.788986  221.50528  188.73383 -1027.59060  0.389086  49064.586
# 279 -47.161606  235.76474  205.15549 -1107.70810  0.069018  55585.010
#
#      Skew_mfcc   Q1_mfcc    Q3_mfcc   IQR_mfcc  MinMax_mfcc  Kurt_mfcc  Label
# 0    -4.104066  0.000000   7.543952   7.543952    1177.3737  14.925378      1
# 1    -4.094527 -0.064156  12.803530  12.867687    1185.5900  14.876037      1
# 2    -4.088933 -0.938724   8.764449   9.703173    1225.9484  14.851157      1
# 3    -4.101749  0.000000  11.384340  11.384340    1120.9485  14.912424      1
# 4    -4.101333  0.000000   9.393891   9.393891    1221.6885  14.910316      1
# ..         ...       ...        ...        ...          ...        ...    ...
# 275  -4.066482 -2.523454  10.922972  13.446426    1248.0366  14.738029      0
# 276  -4.097396  0.000000   4.631042   4.631042    1391.0848  14.903465      0
# 277  -4.050197 -1.776793  10.533521  12.310314    1210.6992  14.664722      0
# 278  -4.090141  0.000000   9.448184   9.448184    1216.3245  14.854414      0
# 279  -4.070286 -3.213782   9.130609  12.344391    1312.8636  14.758332      0
#
# [560 rows x 13 columns]

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Contoh data
datapca_mfcc = df_MFCC.drop(columns=['Label'])
datapca_mfcc = norm(datapca_mfcc)

# Mengubah DataFrame menjadi numpy array
X = datapca_mfcc.values

# Inisialisasi objek PCA dengan jumlah komponen utama yang sama dengan jumlah fitur
num_components = X.shape[1]
pca = PCA(n_components=num_components)

# Lakukan PCA pada tiap fitur (kolom)
pca.fit(X)

# Dapatkan proporsi varians yang dijelaskan oleh tiap komponen utama
explained_variance_ratio = pca.explained_variance_ratio_

# Output proporsi varians (nilai PCA) untuk tiap fitur
for i, ratio in enumerate(explained_variance_ratio):
    print(f"Nilai PCA untuk {datapca_mfcc.columns[i]}: {ratio:.4f}")
# Out:
# Nilai PCA untuk Mean_mfcc: 0.9877
# Nilai PCA untuk Std_mfcc: 0.8350
# Nilai PCA untuk Max_mfcc: 0.7331
# Nilai PCA untuk Min_mfcc: 0.6368
# Nilai PCA untuk Med_mfcc: 0.6209
# Nilai PCA untuk Var_mfcc: 0.6478
# Nilai PCA untuk Skew_mfcc: 0.7505
# Nilai PCA untuk Q1_mfcc: 0.7662
# Nilai PCA untuk Q3_mfcc: 0.7090
# Nilai PCA untuk IQR_mfcc: 0.6438
# Nilai PCA untuk MinMax_mfcc: 0.6692
# Nilai PCA untuk Kurt_mfcc: 0.6141

# %%
df_MFCC = df_MFCC.drop('Min_mfcc', axis=1)
df_MFCC = df_MFCC.drop('Med_mfcc', axis=1)
df_MFCC = df_MFCC.drop('Var_mfcc', axis=1)
df_MFCC = df_MFCC.drop('IQR_mfcc', axis=1)
df_MFCC = df_MFCC.drop('MinMax_mfcc', axis=1)
df_MFCC = df_MFCC.drop('Kurt_mfcc', axis=1)
df_MFCC
# Out:
#      Mean_mfcc   Std_mfcc   Max_mfcc  Skew_mfcc   Q1_mfcc    Q3_mfcc  Label
# 0   -43.426044  219.93683  158.66292  -4.104066  0.000000   7.543952      1
# 1   -41.027546  219.84988  163.84500  -4.094527 -0.064156  12.803530      1
# 2   -42.735283  224.17154  185.06921  -4.088933 -0.938724   8.764449      1
# 3   -38.869167  207.17107  160.68805  -4.101749  0.000000  11.384340      1
# 4   -44.457184  230.23308  155.71140  -4.101333  0.000000   9.393891      1
# ..         ...        ...        ...        ...       ...        ...    ...
# 275 -42.938380  225.72484  187.77933  -4.066482 -2.523454  10.922972      0
# 276 -50.174990  243.28606  266.70163  -4.097396  0.000000   4.631042      0
# 277 -40.708973  212.33914  209.92316  -4.050197 -1.776793  10.533521      0
# 278 -41.788986  221.50528  188.73383  -4.090141  0.000000   9.448184      0
# 279 -47.161606  235.76474  205.15549  -4.070286 -3.213782   9.130609      0
#
# [560 rows x 7 columns]

# %% [markdown]
# **Entropy**

# %%
df_MI_S = pd.read_csv(dwn_url)
df_MI_S = df_MI_S.drop('Unnamed: 0', axis=1)
df_MI_S['Label']=1

# %%
df_MI_S
# Out:
#        Entropy  Label
# 0    13.399662      1
# 1    13.400227      1
# 2    13.399525      1
# 3    13.400404      1
# 4    13.400180      1
# ..         ...    ...
# 275  13.401043      1
# 276  13.399691      1
# 277  13.399147      1
# 278  13.400215      1
# 279  13.400643      1
#
# [280 rows x 2 columns]

# %%
df_N_S = pd.read_csv(dwn_url)
df_N_S = df_N_S.drop('Unnamed: 0', axis=1)
df_N_S['Label']=0

# %%
df_N_S
# Out:
#        Entropy  Label
# 0    13.400763      0
# 1    13.399985      0
# 2    13.400381      0
# 3    13.400293      0
# 4    13.400413      0
# ..         ...    ...
# 275  13.400386      0
# 276  13.400626      0
# 277  13.400406      0
# 278  13.400155      0
# 279  13.400400      0
#
# [280 rows x 2 columns]

# %%
df_S = pd.concat([df_MI_S, df_N_S])
df_S
# Out:
#        Entropy  Label
# 0    13.399662      1
# 1    13.400227      1
# 2    13.399525      1
# 3    13.400404      1
# 4    13.400180      1
# ..         ...    ...
# 275  13.400386      0
# 276  13.400626      0
# 277  13.400406      0
# 278  13.400155      0
# 279  13.400400      0
#
# [560 rows x 2 columns]

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Contoh data
datapca_s = df_S.drop(columns=['Label'])
datapca_s = norm(datapca_s)

# Mengubah DataFrame menjadi numpy array
X = datapca_s.values

# Inisialisasi objek PCA dengan jumlah komponen utama yang sama dengan jumlah fitur
num_components = X.shape[1]
pca = PCA(n_components=num_components)

# Lakukan PCA pada tiap fitur (kolom)
pca.fit(X)

# Dapatkan proporsi varians yang dijelaskan oleh tiap komponen utama
explained_variance_ratio = pca.explained_variance_ratio_

# Output proporsi varians (nilai PCA) untuk tiap fitur
for i, ratio in enumerate(explained_variance_ratio):
    print(f"Nilai PCA untuk {datapca_s.columns[i]}: {ratio:.4f}")
# Out:
# Nilai PCA untuk Entropy: 0.9854

# %% [markdown]
# **PENGGABUNGAN & ACAK**

# %%
df_DWT_MFCC = pd.concat([df_W.drop('Label', axis=1), df_MFCC], axis=1)
df_DWT_MFCC = df_DWT_MFCC.sample(560, random_state=42).reset_index(drop=True)
df_DWT_MFCC
# Out:
#      Mean_wavelet  Std_wavelet   Med_wavelet  Skew_wavelet    Q1_wavelet  \
# 0    3.172988e-08     0.000262  2.280818e-10      0.167248 -3.837985e-06
# 1   -6.565431e-09     0.000085  1.170632e-23     -1.082218 -2.446108e-06
# 2    2.284772e-08     0.000243 -2.894417e-09     -0.696554 -1.087818e-06
# 3    3.444881e-08     0.000248  3.148116e-09     -0.807929 -3.025558e-07
# 4    3.760234e-08     0.000281  1.632967e-09     -1.212518 -5.335380e-07
# ..            ...          ...           ...           ...           ...
# 555 -5.513969e-08     0.000144  3.780651e-09     -0.786405 -5.686318e-07
# 556  2.181387e-08     0.000221 -3.442939e-09      3.195742 -5.416218e-07
# 557 -4.103919e-08     0.000083 -9.960387e-11     -0.169832 -1.948511e-07
# 558  3.533227e-08     0.000182 -7.758139e-22      0.470207 -7.310281e-07
# 559  6.210359e-09     0.000267 -4.060295e-09      4.018408 -6.440437e-07
#
#       IQR_wavelet  MinMax_wavelet  Mean_mfcc   Std_mfcc   Max_mfcc  Skew_mfcc  \
# 0    8.197106e-06        0.018924 -42.188057  206.36282  150.64505  -4.085359
# 1    4.843262e-06        0.005966 -45.929848  241.38426  185.97163  -4.068435
# 2    2.117287e-06        0.011157 -42.776634  219.63580  136.75217  -4.100794
# 3    6.500260e-07        0.006790 -43.732754  231.74303  207.44112  -4.098068
# 4    1.081510e-06        0.017368 -42.514090  210.43529  190.08450  -4.106054
# ..            ...             ...        ...        ...        ...        ...
# 555  1.167161e-06        0.009451 -45.282677  221.05656  159.69629  -4.111376
# 556  1.041774e-06        0.006361 -46.011460  227.48949  139.90292  -4.109344
# 557  3.853638e-07        0.003556 -48.724995  239.00117  176.51984  -4.100745
# 558  1.432905e-06        0.008126 -46.418945  229.71852  199.33120  -4.087997
# 559  1.270827e-06        0.021535 -42.755820  202.63982  174.07901  -4.115148
#
#       Q1_mfcc    Q3_mfcc  Label
# 0   -2.892337   6.101575      0
# 1   -1.962489  12.747309      0
# 2   -0.012842   9.220249      1
# 3    0.000000   9.954310      1
# 4    0.000000   5.515124      0
# ..        ...        ...    ...
# 555  0.000000   5.712025      1
# 556 -0.021497   6.907059      1
# 557  0.000000   4.499527      1
# 558 -0.162370   6.502958      0
# 559  0.000000   2.190152      1
#
# [560 rows x 14 columns]

# %%
df_DWT_SE = pd.concat([df_W.drop('Label', axis=1),df_S], axis=1)
df_DWT_SE = df_DWT_SE.sample(560, random_state=42).reset_index(drop=True)
df_DWT_SE
# Out:
#      Mean_wavelet  Std_wavelet   Med_wavelet  Skew_wavelet    Q1_wavelet  \
# 0    3.172988e-08     0.000262  2.280818e-10      0.167248 -3.837985e-06
# 1   -6.565431e-09     0.000085  1.170632e-23     -1.082218 -2.446108e-06
# 2    2.284772e-08     0.000243 -2.894417e-09     -0.696554 -1.087818e-06
# 3    3.444881e-08     0.000248  3.148116e-09     -0.807929 -3.025558e-07
# 4    3.760234e-08     0.000281  1.632967e-09     -1.212518 -5.335380e-07
# ..            ...          ...           ...           ...           ...
# 555 -5.513969e-08     0.000144  3.780651e-09     -0.786405 -5.686318e-07
# 556  2.181387e-08     0.000221 -3.442939e-09      3.195742 -5.416218e-07
# 557 -4.103919e-08     0.000083 -9.960387e-11     -0.169832 -1.948511e-07
# 558  3.533227e-08     0.000182 -7.758139e-22      0.470207 -7.310281e-07
# 559  6.210359e-09     0.000267 -4.060295e-09      4.018408 -6.440437e-07
#
#       IQR_wavelet  MinMax_wavelet    Entropy  Label
# 0    8.197106e-06        0.018924  13.400209      0
# 1    4.843262e-06        0.005966  13.400620      0
# 2    2.117287e-06        0.011157  13.400085      1
# 3    6.500260e-07        0.006790  13.400079      1
# 4    1.081510e-06        0.017368  13.399586      0
# ..            ...             ...        ...    ...
# 555  1.167161e-06        0.009451  13.399662      1
# 556  1.041774e-06        0.006361  13.399876      1
# 557  3.853638e-07        0.003556  13.400093      1
# 558  1.432905e-06        0.008126  13.400473      0
# 559  1.270827e-06        0.021535  13.399148      1
#
# [560 rows x 9 columns]

# %%
df_MFCC_SE = pd.concat([df_MFCC.drop('Label', axis=1), df_S], axis=1)
df_MFCC_SE = df_MFCC_SE.sample(560, random_state=42).reset_index(drop=True)
df_MFCC_SE
# Out:
#      Mean_mfcc   Std_mfcc   Max_mfcc  Skew_mfcc   Q1_mfcc    Q3_mfcc  \
# 0   -42.188057  206.36282  150.64505  -4.085359 -2.892337   6.101575
# 1   -45.929848  241.38426  185.97163  -4.068435 -1.962489  12.747309
# 2   -42.776634  219.63580  136.75217  -4.100794 -0.012842   9.220249
# 3   -43.732754  231.74303  207.44112  -4.098068  0.000000   9.954310
# 4   -42.514090  210.43529  190.08450  -4.106054  0.000000   5.515124
# ..         ...        ...        ...        ...       ...        ...
# 555 -45.282677  221.05656  159.69629  -4.111376  0.000000   5.712025
# 556 -46.011460  227.48949  139.90292  -4.109344 -0.021497   6.907059
# 557 -48.724995  239.00117  176.51984  -4.100745  0.000000   4.499527
# 558 -46.418945  229.71852  199.33120  -4.087997 -0.162370   6.502958
# 559 -42.755820  202.63982  174.07901  -4.115148  0.000000   2.190152
#
#        Entropy  Label
# 0    13.400209      0
# 1    13.400620      0
# 2    13.400085      1
# 3    13.400079      1
# 4    13.399586      0
# ..         ...    ...
# 555  13.399662      1
# 556  13.399876      1
# 557  13.400093      1
# 558  13.400473      0
# 559  13.399148      1
#
# [560 rows x 8 columns]

# %%
df_DWT_MFCC_SE = pd.concat([df_W.drop('Label', axis=1), df_MFCC.drop('Label', axis=1), df_S], axis=1)
df_DWT_MFCC_SE = df_DWT_MFCC_SE.sample(560, random_state=42).reset_index(drop=True)
df_DWT_MFCC_SE
# Out:
#      Mean_wavelet  Std_wavelet   Med_wavelet  Skew_wavelet    Q1_wavelet  \
# 0    3.172988e-08     0.000262  2.280818e-10      0.167248 -3.837985e-06
# 1   -6.565431e-09     0.000085  1.170632e-23     -1.082218 -2.446108e-06
# 2    2.284772e-08     0.000243 -2.894417e-09     -0.696554 -1.087818e-06
# 3    3.444881e-08     0.000248  3.148116e-09     -0.807929 -3.025558e-07
# 4    3.760234e-08     0.000281  1.632967e-09     -1.212518 -5.335380e-07
# ..            ...          ...           ...           ...           ...
# 555 -5.513969e-08     0.000144  3.780651e-09     -0.786405 -5.686318e-07
# 556  2.181387e-08     0.000221 -3.442939e-09      3.195742 -5.416218e-07
# 557 -4.103919e-08     0.000083 -9.960387e-11     -0.169832 -1.948511e-07
# 558  3.533227e-08     0.000182 -7.758139e-22      0.470207 -7.310281e-07
# 559  6.210359e-09     0.000267 -4.060295e-09      4.018408 -6.440437e-07
#
#       IQR_wavelet  MinMax_wavelet  Mean_mfcc   Std_mfcc   Max_mfcc  Skew_mfcc  \
# 0    8.197106e-06        0.018924 -42.188057  206.36282  150.64505  -4.085359
# 1    4.843262e-06        0.005966 -45.929848  241.38426  185.97163  -4.068435
# 2    2.117287e-06        0.011157 -42.776634  219.63580  136.75217  -4.100794
# 3    6.500260e-07        0.006790 -43.732754  231.74303  207.44112  -4.098068
# 4    1.081510e-06        0.017368 -42.514090  210.43529  190.08450  -4.106054
# ..            ...             ...        ...        ...        ...        ...
# 555  1.167161e-06        0.009451 -45.282677  221.05656  159.69629  -4.111376
# 556  1.041774e-06        0.006361 -46.011460  227.48949  139.90292  -4.109344
# 557  3.853638e-07        0.003556 -48.724995  239.00117  176.51984  -4.100745
# 558  1.432905e-06        0.008126 -46.418945  229.71852  199.33120  -4.087997
# 559  1.270827e-06        0.021535 -42.755820  202.63982  174.07901  -4.115148
#
#       Q1_mfcc    Q3_mfcc    Entropy  Label
# 0   -2.892337   6.101575  13.400209      0
# 1   -1.962489  12.747309  13.400620      0
# 2   -0.012842   9.220249  13.400085      1
# 3    0.000000   9.954310  13.400079      1
# 4    0.000000   5.515124  13.399586      0
# ..        ...        ...        ...    ...
# 555  0.000000   5.712025  13.399662      1
# 556 -0.021497   6.907059  13.399876      1
# 557  0.000000   4.499527  13.400093      1
# 558 -0.162370   6.502958  13.400473      0
# 559  0.000000   2.190152  13.399148      1
#
# [560 rows x 15 columns]

# %% [markdown]
# **ACAK TIAP FITUR**

# %%
df_W = df_W.sample(560, random_state=42).reset_index(drop=True)
df_W
# Out:
#      Mean_wavelet  Std_wavelet   Med_wavelet  Skew_wavelet    Q1_wavelet  \
# 0    3.172988e-08     0.000262  2.280818e-10      0.167248 -3.837985e-06
# 1   -6.565431e-09     0.000085  1.170632e-23     -1.082218 -2.446108e-06
# 2    2.284772e-08     0.000243 -2.894417e-09     -0.696554 -1.087818e-06
# 3    3.444881e-08     0.000248  3.148116e-09     -0.807929 -3.025558e-07
# 4    3.760234e-08     0.000281  1.632967e-09     -1.212518 -5.335380e-07
# ..            ...          ...           ...           ...           ...
# 555 -5.513969e-08     0.000144  3.780651e-09     -0.786405 -5.686318e-07
# 556  2.181387e-08     0.000221 -3.442939e-09      3.195742 -5.416218e-07
# 557 -4.103919e-08     0.000083 -9.960387e-11     -0.169832 -1.948511e-07
# 558  3.533227e-08     0.000182 -7.758139e-22      0.470207 -7.310281e-07
# 559  6.210359e-09     0.000267 -4.060295e-09      4.018408 -6.440437e-07
#
#       IQR_wavelet  MinMax_wavelet  Label
# 0    8.197106e-06        0.018924      0
# 1    4.843262e-06        0.005966      0
# 2    2.117287e-06        0.011157      1
# 3    6.500260e-07        0.006790      1
# 4    1.081510e-06        0.017368      0
# ..            ...             ...    ...
# 555  1.167161e-06        0.009451      1
# 556  1.041774e-06        0.006361      1
# 557  3.853638e-07        0.003556      1
# 558  1.432905e-06        0.008126      0
# 559  1.270827e-06        0.021535      1
#
# [560 rows x 8 columns]

# %%
df_MFCC = df_MFCC.sample(560, random_state=42).reset_index(drop=True)
df_MFCC
# Out:
#      Mean_mfcc   Std_mfcc   Max_mfcc  Skew_mfcc   Q1_mfcc    Q3_mfcc  Label
# 0   -42.188057  206.36282  150.64505  -4.085359 -2.892337   6.101575      0
# 1   -45.929848  241.38426  185.97163  -4.068435 -1.962489  12.747309      0
# 2   -42.776634  219.63580  136.75217  -4.100794 -0.012842   9.220249      1
# 3   -43.732754  231.74303  207.44112  -4.098068  0.000000   9.954310      1
# 4   -42.514090  210.43529  190.08450  -4.106054  0.000000   5.515124      0
# ..         ...        ...        ...        ...       ...        ...    ...
# 555 -45.282677  221.05656  159.69629  -4.111376  0.000000   5.712025      1
# 556 -46.011460  227.48949  139.90292  -4.109344 -0.021497   6.907059      1
# 557 -48.724995  239.00117  176.51984  -4.100745  0.000000   4.499527      1
# 558 -46.418945  229.71852  199.33120  -4.087997 -0.162370   6.502958      0
# 559 -42.755820  202.63982  174.07901  -4.115148  0.000000   2.190152      1
#
# [560 rows x 7 columns]

# %%
df_S = df_S.sample(560, random_state=42).reset_index(drop=True)
df_S
# Out:
#        Entropy  Label
# 0    13.400209      0
# 1    13.400620      0
# 2    13.400085      1
# 3    13.400079      1
# 4    13.399586      0
# ..         ...    ...
# 555  13.399662      1
# 556  13.399876      1
# 557  13.400093      1
# 558  13.400473      0
# 559  13.399148      1
#
# [560 rows x 2 columns]

# %% [markdown]
# **SKENARIO 1**

# %%
def norm(df):
  df = (df - df.min()) / (df.max() - df.min())
  return df

# %% [markdown]
# DWT

# %%
X = df_W.drop('Label', axis=1)
y = df_W.Label

# %%
X = norm(X)
X
# Out:
#      Mean_wavelet  Std_wavelet  Med_wavelet  Skew_wavelet  Q1_wavelet  \
# 0        0.568809     0.054673     0.409831      0.533150    0.681394
# 1        0.557583     0.016037     0.406286      0.504337    0.796939
# 2        0.566205     0.050611     0.361305      0.513230    0.909696
# 3        0.569606     0.051659     0.455210      0.510662    0.974884
# 4        0.570530     0.058787     0.431664      0.501332    0.955709
# ..            ...          ...          ...           ...         ...
# 555      0.543345     0.028955     0.465040      0.511158    0.952796
# 556      0.565902     0.045796     0.352781      0.602990    0.955038
# 557      0.547478     0.015550     0.404739      0.525377    0.983825
# 558      0.569865     0.037334     0.406286      0.540137    0.939314
# 559      0.561328     0.055743     0.343187      0.621962    0.946535
#
#      IQR_wavelet  MinMax_wavelet
# 0       0.344614        0.042660
# 1       0.203615        0.012979
# 2       0.089013        0.024871
# 3       0.027328        0.014868
# 4       0.045468        0.039095
# ..           ...             ...
# 555     0.049069        0.020962
# 556     0.043797        0.013886
# 557     0.016201        0.007461
# 558     0.060241        0.017928
# 559     0.053427        0.048640
#
# [560 rows x 7 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9880952380952381
# Sensitivity: 0.9887640449438202
# Specificity: 0.9873417721518988

# %% [markdown]
# MFCC

# %%
X = df_MFCC.drop('Label', axis=1)
y = df_MFCC.Label

# %%
X = norm(X)
X
# Out:
#      Mean_mfcc  Std_mfcc  Max_mfcc  Skew_mfcc   Q1_mfcc   Q3_mfcc
# 0     0.604765  0.552997  0.373070   0.376129  0.645053  0.398643
# 1     0.440595  0.957750  0.534502   0.546852  0.759164  0.832838
# 2     0.578941  0.706396  0.309584   0.220422  0.998424  0.602400
# 3     0.536992  0.846323  0.632612   0.247926  1.000000  0.650359
# 4     0.590460  0.600063  0.553297   0.167364  1.000000  0.360327
# ..         ...       ...       ...        ...       ...       ...
# 555   0.468989  0.722816  0.414432   0.113675  1.000000  0.373192
# 556   0.437014  0.797164  0.323982   0.134176  0.997362  0.451269
# 557   0.317959  0.930207  0.491310   0.220920  1.000000  0.293974
# 558   0.419136  0.822925  0.595552   0.349513  0.980074  0.424867
# 559   0.579854  0.509969  0.480157   0.075627  1.000000  0.143092
#
# [560 rows x 6 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9940476190476191
# Sensitivity: 0.9955904022888529
# Specificity: 0.9873417721518988

# %% [markdown]
# Entropy

# %%
X = df_S.drop('Label', axis=1)
y = df_S.Label

# %%
X = norm(X)
X
# Out:
#       Entropy
# 0    0.999467
# 1    0.999674
# 2    0.999405
# 3    0.999402
# 4    0.999154
# ..        ...
# 555  0.999193
# 556  0.999300
# 557  0.999409
# 558  0.999600
# 559  0.998934
#
# [560 rows x 1 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9978980456954788
# Sensitivity: 0.996708943637951
# Specificity: 0.9986715818221968

# %% [markdown]
# SKENARIO 2

# %% [markdown]
# DWT dan MFCC

# %%
X = df_DWT_MFCC.drop('Label', axis=1)
y = df_DWT_MFCC.Label
X = norm(X)
X
# Out:
#      Mean_wavelet  Std_wavelet  Med_wavelet  Skew_wavelet  Q1_wavelet  \
# 0        0.568809     0.054673     0.409831      0.533150    0.681394
# 1        0.557583     0.016037     0.406286      0.504337    0.796939
# 2        0.566205     0.050611     0.361305      0.513230    0.909696
# 3        0.569606     0.051659     0.455210      0.510662    0.974884
# 4        0.570530     0.058787     0.431664      0.501332    0.955709
# ..            ...          ...          ...           ...         ...
# 555      0.543345     0.028955     0.465040      0.511158    0.952796
# 556      0.565902     0.045796     0.352781      0.602990    0.955038
# 557      0.547478     0.015550     0.404739      0.525377    0.983825
# 558      0.569865     0.037334     0.406286      0.540137    0.939314
# 559      0.561328     0.055743     0.343187      0.621962    0.946535
#
#      IQR_wavelet  MinMax_wavelet  Mean_mfcc  Std_mfcc  Max_mfcc  Skew_mfcc  \
# 0       0.344614        0.042660   0.604765  0.552997  0.373070   0.376129
# 1       0.203615        0.012979   0.440595  0.957750  0.534502   0.546852
# 2       0.089013        0.024871   0.578941  0.706396  0.309584   0.220422
# 3       0.027328        0.014868   0.536992  0.846323  0.632612   0.247926
# 4       0.045468        0.039095   0.590460  0.600063  0.553297   0.167364
# ..           ...             ...        ...       ...       ...        ...
# 555     0.049069        0.020962   0.468989  0.722816  0.414432   0.113675
# 556     0.043797        0.013886   0.437014  0.797164  0.323982   0.134176
# 557     0.016201        0.007461   0.317959  0.930207  0.491310   0.220920
# 558     0.060241        0.017928   0.419136  0.822925  0.595552   0.349513
# 559     0.053427        0.048640   0.579854  0.509969  0.480157   0.075627
#
#       Q1_mfcc   Q3_mfcc
# 0    0.645053  0.398643
# 1    0.759164  0.832838
# 2    0.998424  0.602400
# 3    1.000000  0.650359
# 4    1.000000  0.360327
# ..        ...       ...
# 555  1.000000  0.373192
# 556  0.997362  0.451269
# 557  1.000000  0.293974
# 558  0.980074  0.424867
# 559  1.000000  0.143092
#
# [560 rows x 13 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9880952380952381
# Sensitivity: 0.9887640449438202
# Specificity: 0.9873417721518988

# %% [markdown]
# DWT dan SE

# %%
X = df_DWT_SE.drop('Label', axis=1)
y = df_DWT_SE.Label
X = norm(X)
X
# Out:
#      Mean_wavelet  Std_wavelet  Med_wavelet  Skew_wavelet  Q1_wavelet  \
# 0        0.568809     0.054673     0.409831      0.533150    0.681394
# 1        0.557583     0.016037     0.406286      0.504337    0.796939
# 2        0.566205     0.050611     0.361305      0.513230    0.909696
# 3        0.569606     0.051659     0.455210      0.510662    0.974884
# 4        0.570530     0.058787     0.431664      0.501332    0.955709
# ..            ...          ...          ...           ...         ...
# 555      0.543345     0.028955     0.465040      0.511158    0.952796
# 556      0.565902     0.045796     0.352781      0.602990    0.955038
# 557      0.547478     0.015550     0.404739      0.525377    0.983825
# 558      0.569865     0.037334     0.406286      0.540137    0.939314
# 559      0.561328     0.055743     0.343187      0.621962    0.946535
#
#      IQR_wavelet  MinMax_wavelet   Entropy
# 0       0.344614        0.042660  0.999467
# 1       0.203615        0.012979  0.999674
# 2       0.089013        0.024871  0.999405
# 3       0.027328        0.014868  0.999402
# 4       0.045468        0.039095  0.999154
# ..           ...             ...       ...
# 555     0.049069        0.020962  0.999193
# 556     0.043797        0.013886  0.999300
# 557     0.016201        0.007461  0.999409
# 558     0.060241        0.017928  0.999600
# 559     0.053427        0.048640  0.998934
#
# [560 rows x 8 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9880952380952381
# Sensitivity: 0.9887640449438202
# Specificity: 0.9873417721518988

# %% [markdown]
# MFCC dan SE

# %%
X = df_MFCC_SE.drop('Label', axis=1)
y = df_MFCC_SE.Label
X = norm(X)
X
# Out:
#      Mean_mfcc  Std_mfcc  Max_mfcc  Skew_mfcc   Q1_mfcc   Q3_mfcc   Entropy
# 0     0.604765  0.552997  0.373070   0.376129  0.645053  0.398643  0.999467
# 1     0.440595  0.957750  0.534502   0.546852  0.759164  0.832838  0.999674
# 2     0.578941  0.706396  0.309584   0.220422  0.998424  0.602400  0.999405
# 3     0.536992  0.846323  0.632612   0.247926  1.000000  0.650359  0.999402
# 4     0.590460  0.600063  0.553297   0.167364  1.000000  0.360327  0.999154
# ..         ...       ...       ...        ...       ...       ...       ...
# 555   0.468989  0.722816  0.414432   0.113675  1.000000  0.373192  0.999193
# 556   0.437014  0.797164  0.323982   0.134176  0.997362  0.451269  0.999300
# 557   0.317959  0.930207  0.491310   0.220920  1.000000  0.293974  0.999409
# 558   0.419136  0.822925  0.595552   0.349513  0.980074  0.424867  0.999600
# 559   0.579854  0.509969  0.480157   0.075627  1.000000  0.143092  0.998934
#
# [560 rows x 7 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9940476190476191
# Sensitivity: 0.9963769883709888
# Specificity: 0.9873417721518988

# %% [markdown]
# SKENARIO 3

# %% [markdown]
# DWT dan MFCC dan SE

# %%
X = df_DWT_MFCC_SE.drop('Label', axis=1)
y = df_DWT_MFCC_SE.Label
X = norm(X)
X
# Out:
#      Mean_wavelet  Std_wavelet  Med_wavelet  Skew_wavelet  Q1_wavelet  \
# 0        0.568809     0.054673     0.409831      0.533150    0.681394
# 1        0.557583     0.016037     0.406286      0.504337    0.796939
# 2        0.566205     0.050611     0.361305      0.513230    0.909696
# 3        0.569606     0.051659     0.455210      0.510662    0.974884
# 4        0.570530     0.058787     0.431664      0.501332    0.955709
# ..            ...          ...          ...           ...         ...
# 555      0.543345     0.028955     0.465040      0.511158    0.952796
# 556      0.565902     0.045796     0.352781      0.602990    0.955038
# 557      0.547478     0.015550     0.404739      0.525377    0.983825
# 558      0.569865     0.037334     0.406286      0.540137    0.939314
# 559      0.561328     0.055743     0.343187      0.621962    0.946535
#
#      IQR_wavelet  MinMax_wavelet  Mean_mfcc  Std_mfcc  Max_mfcc  Skew_mfcc  \
# 0       0.344614        0.042660   0.604765  0.552997  0.373070   0.376129
# 1       0.203615        0.012979   0.440595  0.957750  0.534502   0.546852
# 2       0.089013        0.024871   0.578941  0.706396  0.309584   0.220422
# 3       0.027328        0.014868   0.536992  0.846323  0.632612   0.247926
# 4       0.045468        0.039095   0.590460  0.600063  0.553297   0.167364
# ..           ...             ...        ...       ...       ...        ...
# 555     0.049069        0.020962   0.468989  0.722816  0.414432   0.113675
# 556     0.043797        0.013886   0.437014  0.797164  0.323982   0.134176
# 557     0.016201        0.007461   0.317959  0.930207  0.491310   0.220920
# 558     0.060241        0.017928   0.419136  0.822925  0.595552   0.349513
# 559     0.053427        0.048640   0.579854  0.509969  0.480157   0.075627
#
#       Q1_mfcc   Q3_mfcc   Entropy
# 0    0.645053  0.398643  0.999467
# 1    0.759164  0.832838  0.999674
# 2    0.998424  0.602400  0.999405
# 3    1.000000  0.650359  0.999402
# 4    1.000000  0.360327  0.999154
# ..        ...       ...       ...
# 555  1.000000  0.373192  0.999193
# 556  0.997362  0.451269  0.999300
# 557  1.000000  0.293974  0.999409
# 558  0.980074  0.424867  0.999600
# 559  1.000000  0.143092  0.998934
#
# [560 rows x 14 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score

# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi model KNN dengan perbaikan yang diinginkan
k = 7  # ukuran ketetanggaan
weights = 'uniform'  # menggunakan bobot jarak dalam perhitungan probabilitas
algorithm = 'auto'  # menggunakan struktur data auto
metric = 'manhattan'  # menggunakan fungsi jarak Euclidean

knn = KNeighborsClassifier(n_neighbors=k, weights=weights, algorithm=algorithm, metric=metric)

# Melatih model KNN
knn.fit(X_train_scaled, y_train)

# Memprediksi kelas untuk data uji
y_pred = knn.predict(X_test_scaled)

# Menghitung akurasi model
accuracy = knn.score(X_test_scaled, y_test)
print(f"Akurasi model: {accuracy}")

sensitivity = recall_score(y_test, y_pred)
specificity = recall_score(y_test, y_pred, pos_label=0)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Akurasi model: 0.9880952380952381
# Sensitivity: 0.9887640449438202
# Specificity: 0.9873417721518988
